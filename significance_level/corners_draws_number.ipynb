# %%
import sys
sys.path.append('..')
from utilities.utilities import *
import time
# Out:
# 2025-01-30 15:37:03.612 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
games = pd.DataFrame()
driver = WebDriverUtility.init_driver(headless=False)
stc = SingleTeamCornersUtility(driver=driver)

for season in [22, 23, 24]:
    team_codes = pd.read_csv(fr"C:\Users\leoac\OneDrive - Università degli Studi di Milano\Data science\Football\Betting\Corners\corners-betting\team_codes\teams_{season}-{season+1}.csv")
    for i, (team, code) in team_codes.iterrows():
        print(team, code, season)
        time.sleep(1)
        team_df = stc.single_team(code=code, team=team, season=season)
        team_df['season'] = f"{season}-{season+1}"
        games = pd.concat((games, team_df),axis=0)
games # games are duplicated
# Out:
# Atalanta 922493f3 22
# Bologna 1d8099f8 22
# Cremonese 9aad3a77 22
# Empoli a3d88bd8 22
# Fiorentina 421387cf 22
# Hellas Verona 0e72edf2 22
# Inter d609edc0 22
# Juventus e0652b02 22
# Lazio 7213da33 22
# Lecce ffcbe334 22
# Milan dc56fe14 22
# Monza 21680aa4 22
# Napoli d48ad4ff 22
# Roma cf74a709 22
# Salernitana c5577084 22
# Sampdoria 8ff9e3b3 22
# Sassuolo e2befd26 22
# Spezia 68449f6d 22
# Torino 105360fe 22
# Udinese 04eea015 22
# Atalanta 922493f3 23
# Bologna 1d8099f8 23
# Cagliari c4260e09 23
# Empoli a3d88bd8 23
# Fiorentina 421387cf 23
# Frosinone 6a7ad59d 23
# Genoa 658bf2de 23
# Hellas Verona 0e72edf2 23
# Inter d609edc0 23
# Juventus e0652b02 23
# Lazio 7213da33 23
# Lecce ffcbe334 23
# Milan dc56fe14 23
# Monza 21680aa4 23
# Napoli d48ad4ff 23
# Roma cf74a709 23
# Salernitana c5577084 23
# Sassuolo e2befd26 23
# Torino 105360fe 23
# Udinese 04eea015 23
# Atalanta 922493f3 24
# Bologna 1d8099f8 24
# Cagliari c4260e09 24
# Como 28c9c3cd 24
# Empoli a3d88bd8 24
# Fiorentina 421387cf 24
# Genoa 658bf2de 24
# Hellas Verona 0e72edf2 24
# Inter d609edc0 24
# Juventus e0652b02 24
# Lazio 7213da33 24
# Lecce ffcbe334 24
# Milan dc56fe14 24
# Monza 21680aa4 24
# Napoli d48ad4ff 24
# Parma eab4234c 24
# Roma cf74a709 24
# Torino 105360fe 24
# Udinese 04eea015 24
# Venezia af5d5982 24
#                     Date Venue Result   GF GA       Opponent  Corners for  \
# Round
# Matchweek 1   2022-08-13  Away      W  2.0  0      Sampdoria            2
# Matchweek 2   2022-08-21  Home      D  1.0  1          Milan            4
# Matchweek 3   2022-08-28  Away      W  1.0  0  Hellas Verona            6
# Matchweek 4   2022-09-01  Home      W  3.0  1         Torino            7
# Matchweek 5   2022-09-05  Away      W  2.0  0          Monza            9
# ...                  ...   ...    ...  ... ..            ...          ...
# Matchweek 18  2024-12-29  Away      L  0.0  1         Napoli            4
# Matchweek 19  2025-01-04  Home      D  1.0  1         Empoli            2
# Matchweek 20  2025-01-12  Home      L  0.0  1          Inter            4
# Matchweek 21  2025-01-19  Away      D  1.0  1          Parma            2
# Matchweek 22  2025-01-27  Home      D  1.0  1  Hellas Verona            7
#
#               Corners against Outcome  Corners difference season
# Round
# Matchweek 1               3.0  Defeat                  -1  22-23
# Matchweek 2               6.0  Defeat                  -2  22-23
# Matchweek 3               7.0  Defeat                  -1  22-23
# Matchweek 4               2.0     Win                   5  22-23
# Matchweek 5               4.0     Win                   5  22-23
# ...                       ...     ...                 ...    ...
# Matchweek 18             14.0  Defeat                 -10  24-25
# Matchweek 19              8.0  Defeat                  -6  24-25
# Matchweek 20              5.0  Defeat                  -1  24-25
# Matchweek 21              8.0  Defeat                  -6  24-25
# Matchweek 22              9.0  Defeat                  -2  24-25
#
# [1958 rows x 11 columns]

# %%
# Number of matches ended with corners draw
corners_draw = games.Outcome.value_counts()['Draw']/2
# Percentual of matches ended with corners draw.
perc_corners_draw = corners_draw/(len(games)/2)*100
# Significance level to perform hypotesis testing
alpha = round(100 - perc_corners_draw,2)

# %%
with open(r"C:\Users\leoac\OneDrive - Università degli Studi di Milano\Data science\Football\Betting\Corners\corners-betting\significance_level\alpha.txt", 'w') as file:
    file.write(str(alpha))
